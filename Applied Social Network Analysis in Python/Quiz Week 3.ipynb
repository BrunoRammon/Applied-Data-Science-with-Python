# %%
# %matplotlib notebook
import networkx as nx
import matplotlib.pyplot as plt


G=nx.DiGraph()

G.add_edge('A','B')
G.add_edge('B','A')
G.add_edge('A','C')
G.add_edge('C','D')
G.add_edge('D','C')

plt.figure(figsize=(7,8))
# pos = nx.circular_layout(G)
nx.draw_networkx(G)
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
print(nx.pagerank(G, alpha=0.5))
print(nx.pagerank(G, alpha=0.8))
print(nx.pagerank(G, alpha=0.9))
print(nx.pagerank(G, alpha=0.95))
# Out:
# {'A': 0.21428680419921875, 'B': 0.1785717010498047, 'C': 0.3214282989501953, 'D': 0.28571319580078125}
# {'A': 0.13235426576459627, 'B': 0.1029417063058385, 'C': 0.3970582936941615, 'D': 0.36764573423540375}
# {'A': 0.07983327489935103, 'B': 0.06092586099927893, 'C': 0.4390741390007211, 'D': 0.420166725100649}
# {'A': 0.04442211856731087, 'B': 0.03360050631947267, 'C': 0.46639949368052747, 'D': 0.4555778814326893}

# %%
G=nx.DiGraph()

G.add_edge('A','B')
G.add_edge('C','A')
G.add_edge('B','C')
G.add_edge('D','C')
G.add_edge('A','C')

plt.figure(figsize=(7,8))
# pos = nx.circular_layout(G)
nx.draw_networkx(G)
# Out:
# <img src="data:image/png;base64,..." width="699.4166666666667">

# %%
print(nx.pagerank(G, alpha=1, max_iter=2))
# Out:
# ---------------------------------------------------------------------------
# NetworkXError                             Traceback (most recent call last)
# <ipython-input-14-36393e2b658d> in <module>()
# ----> 1 print(nx.pagerank(G, alpha=1, max_iter=2))
#
# <decorator-gen-228> in pagerank(G, alpha, personalization, max_iter, tol, nstart, weight, dangling)
#
# /opt/conda/lib/python3.6/site-packages/networkx/utils/decorators.py in _not_implemented_for(f, *args, **kwargs)
#      66                                             ' '.join(graph_types))
#      67         else:
# ---> 68             return f(*args,**kwargs)
#      69     return _not_implemented_for
#      70
#
# /opt/conda/lib/python3.6/site-packages/networkx/algorithms/link_analysis/pagerank_alg.py in pagerank(G, alpha, personalization, max_iter, tol, nstart, weight, dangling)
#     156             return x
#     157     raise NetworkXError('pagerank: power iteration failed to converge '
# ...
